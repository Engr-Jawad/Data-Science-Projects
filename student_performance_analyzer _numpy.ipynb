# %% [markdown]
# # Student Exam Data Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # creating numpy array of math ,science and english

# %%
number_of_students = 100
math_marks = np.random.randint(40,101,number_of_students)
science_marks = np.random.randint(40,101,number_of_students)
english_marks = np.random.randint(40,101,number_of_students)
print("math_marks : ",math_marks[:])
print("\n")
print("science_marks : ", science_marks[:])
print("\n")

print("english marks : ", english_marks[:])
# Out:
# math_marks :  [ 72  77  97  78  46  44  50  83  93  84  79  69  78  54  65  72  86  73
#   95  55  59  72  75  80  52  78  96  80  54  96  67  61  58  61  75  89
#   76  78  51  96  49  62  60  62  99  54  46  90  76  45  41  84  40  69
#   51  72  49  56  81  54  79  72  96  45  40  46  81  91  54  74  88  94
#   55  41  45  56  75  57  92  61  55  72  80  75  67  54  55  99  61  68
#  100  77  66  50  58  81 100  78  57  70]
#
#
# science_marks :  [ 54  49  80  89  79  43  91  57  50  80  66  67  83  78  94  87  67  85
#   54  69  46  58  96  50  84  72  42  60  65  40  49  99  97  46  90  94
#   74  97 100  51  61  51  69  72  90  87  99  81  83  98  63  67  57  90
#   90  71  45  86  66  42  53  94  56  89  86  63  81  57  69  87  75  54
#   97  62  57  86  87  78  84  97  44  75  51  51  98  49  41  79  40  69
#   41  62  68  91  71  55  46  55  85  55]
#
#
# english marks :  [ 97  56  96  61  52  42  78  64  59  89  56  41  70  52  95  77  66  59
#   81  92  43  64 100  96  93  65  70  91  75  81  88  99  78  75  72  55
#   51  89  74  82  91  45  91  72  40  44  84  45  43  53  85  57  87  90
#   53  85  47  66  61  43  82  65  43  60  86  75  55  48  56  71  55  51
#   59  73  95  40  85  41  68  56  55  47  48  53  87  55  79  60  89  86
#   94  73  84  40  92  44  75  41  51  60]

# %% [markdown]
# # creating Dataframe

# %%
std_ids=[]
for i in range(1,number_of_students +1):
    std_ids.append(f"S{i:03}")
df = pd.DataFrame({
                      "students_id":std_ids,
                      "math_marks":math_marks,
                      "science_marks":science_marks,
                      "english_marks":english_marks})
df
# Out:
#    students_id  math_marks  science_marks  english_marks
# 0         S001          72             54             97
# 1         S002          77             49             56
# 2         S003          97             80             96
# 3         S004          78             89             61
# 4         S005          46             79             52
# ..         ...         ...            ...            ...
# 95        S096          81             55             44
# 96        S097         100             46             75
# 97        S098          78             55             41
# 98        S099          57             85             51
# 99        S100          70             55             60
#
# [100 rows x 4 columns]

# %%
average_marks_maths = df["math_marks"].mean()
print(average_marks_maths)
average_marks_science = df["science_marks"].mean()
print(average_marks_science)
average_marks_english = df["english_marks"].mean()
print(average_marks_english)
print("\n\n")
highest_marks = df[["math_marks","science_marks","english_marks"]].max()
print("highest marks in each subject : \n", highest_marks)
print("\n\n")
lowest_marks = df[["math_marks","science_marks","english_marks"]].min()
print("lowest marks in each subject : \n",lowest_marks)
print("\n\n")
total_marks = df["total_marks"]= df[["math_marks","science_marks","english_marks"]].sum(axis=1)
df["percentage"]= (df["total_marks"]/300 )* 100
def grade(percentage):
    if percentage >= 90 :
        return "A"
    elif percentage >= 80 :
        return "B"
    elif percentage >= 70 :
        return "c"
    elif percentage >= 60:
        return "D"
    else:
        return "F"
df["grade"] = df["percentage"].apply(grade)
df
# Out:
# 69.09
# 70.38
# 67.83
#
#
#
# highest marks in each subject :
#  math_marks       100
# science_marks    100
# english_marks    100
# dtype: int64
#
#
#
# lowest marks in each subject :
#  math_marks       40
# science_marks    40
# english_marks    40
# dtype: int64
#    students_id  math_marks  science_marks  english_marks  total_marks  \
# 0         S001          72             54             97          223
# 1         S002          77             49             56          182
# 2         S003          97             80             96          273
# 3         S004          78             89             61          228
# 4         S005          46             79             52          177
# ..         ...         ...            ...            ...          ...
# 95        S096          81             55             44          180
# 96        S097         100             46             75          221
# 97        S098          78             55             41          174
# 98        S099          57             85             51          193
# 99        S100          70             55             60          185
#
#     percentage grade
# 0    74.333333     c
# 1    60.666667     D
# 2    91.000000     A
# 3    76.000000     c
# 4    59.000000     F
# ..         ...   ...
# 95   60.000000     D
# 96   73.666667     c
# 97   58.000000     F
# 98   64.333333     D
# 99   61.666667     D
#
# [100 rows x 7 columns]

# %% [markdown]
# # # top five students on the basis of percentage

# %%
top_five = df.sort_values(by="percentage",ascending=False).head(5)
print("top five students : \n",top_five)
# Out:
# top five students :
#     students_id  math_marks  science_marks  english_marks  total_marks  \
# 2         S003          97             80             96          273
# 22        S023          75             96            100          271
# 37        S038          78             97             89          264
# 31        S032          61             99             99          259
# 14        S015          65             94             95          254
#
#     percentage grade
# 2    91.000000     A
# 22   90.333333     A
# 37   88.000000     B
# 31   86.333333     B
# 14   84.666667     B

# %%
num_of_grade_a = (df["grade"]== "A").sum()
num_of_grade_f = (df["grade"] == "F").sum()
print("number of students take grade A : ",num_of_grade_a)
print("number of students who failed : ",num_of_grade_f)

# %% [markdown]
# # # Bar Chart (Average Marks of Each Subject)

# %%
subjects = [" math_marks",  "science_marks",  "english_marks "]
average = [df["math_marks"].mean(),df["science_marks"].mean(),df["english_marks"].mean()]
plt.Figure(figsize=(6,4))
plt.bar(subjects,average,color ="green")
plt.xlabel("subjects")
plt.ylabel("average marks")
plt.title("average marks of each subjects")
plt.show()

# %% [markdown]
# # Histogram (Math Marks Distribution)

# %%
plt.Figure(figsize=(8,9))
plt.hist(df["math_marks"],bins=10)
plt.title("distribution of math marks ")
plt.xlabel("math_marks")
plt.ylabel("number of students")
plt.show()

# %% [markdown]
# #  Line Chart (Student ID vs Average Marks)

# %%
plt.Figure(figsize=(10,15))
plt.plot(df["students_id"],df["percentage"],marker="o")
plt.title("student average marks")
plt.xlabel("student id")
plt.ylabel("average marks")
plt.show()
