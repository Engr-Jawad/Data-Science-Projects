# %% [markdown]
# # Data loading

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/jawad/my_jupyter_env/Data_Science_Projects/Urban-Road-Safety-Near-Miss-Analysis/urban_near_miss_dataset_12000.csv")
# Out:
#        Record_ID        City Day_of_Week  Hour Weather Traffic_Level  \
# 0              1    Peshawar    Thursday     6  Cloudy        Medium
# 1              2     Karachi      Friday    19   Clear        Medium
# 2              3  Rawalpindi      Friday    14   Clear        Medium
# 3              4    Peshawar      Sunday    10    Rain          High
# 4              5  Rawalpindi    Saturday     7    Rain        Severe
# ...          ...         ...         ...   ...     ...           ...
# 11995      11996      Quetta     Tuesday    19  Cloudy        Medium
# 11996      11997    Peshawar    Thursday    18    Rain        Severe
# 11997      11998      Lahore      Sunday    13   Clear           Low
# 11998      11999  Rawalpindi      Monday     1   Clear        Medium
# 11999      12000     Karachi      Friday     4   Clear        Medium
#
#       Vehicle_Type    Road_Type  Speed_Limit_kmh  Average_Speed_kmh  \
# 0       Motorcycle    Main Road               60               51.7
# 1              Bus  Residential               50               51.8
# 2         Rickshaw  Residential               50               74.7
# 3              Car    Main Road               60               39.4
# 4         Rickshaw      Highway              100               62.5
# ...            ...          ...              ...                ...
# 11995   Motorcycle       Market               50               37.3
# 11996     Rickshaw  Residential               50               22.7
# 11997          Van  Residential               50               41.7
# 11998          Bus       Market               50               41.8
# 11999          Van  Residential               50               27.9
#
#        Pedestrian_Count  Visibility_Percent  Near_Miss_Score  Incident
# 0                    11                82.3             40.2         0
# 1                    10                91.1             31.6         0
# 2                    11                82.2             44.8         0
# 3                     7                74.0             35.6         0
# 4                     8                97.3             57.1         1
# ...                 ...                 ...              ...       ...
# 11995                31                74.5             37.9         0
# 11996                10                84.4             76.3         1
# 11997                 8                98.3             20.8         0
# 11998                25                87.0             25.9         0
# 11999                 3                92.5             41.5         0
#
# [12000 rows x 14 columns]

# %% [markdown]
# # ist five rows of the  data sets

# %%
df.head()
# Out:
#    Record_ID        City Day_of_Week  Hour Weather Traffic_Level Vehicle_Type  \
# 0          1    Peshawar    Thursday     6  Cloudy        Medium   Motorcycle
# 1          2     Karachi      Friday    19   Clear        Medium          Bus
# 2          3  Rawalpindi      Friday    14   Clear        Medium     Rickshaw
# 3          4    Peshawar      Sunday    10    Rain          High          Car
# 4          5  Rawalpindi    Saturday     7    Rain        Severe     Rickshaw
#
#      Road_Type  Speed_Limit_kmh  Average_Speed_kmh  Pedestrian_Count  \
# 0    Main Road               60               51.7                11
# 1  Residential               50               51.8                10
# 2  Residential               50               74.7                11
# 3    Main Road               60               39.4                 7
# 4      Highway              100               62.5                 8
#
#    Visibility_Percent  Near_Miss_Score  Incident
# 0                82.3             40.2         0
# 1                91.1             31.6         0
# 2                82.2             44.8         0
# 3                74.0             35.6         0
# 4                97.3             57.1         1

# %% [markdown]
# # shape of the data sets

# %%
df.shape
# Out:
# (12000, 14)

# %% [markdown]
# # columns in the data set

# %%
df.columns
# Out:
# Index(['Record_ID', 'City', 'Day_of_Week', 'Hour', 'Weather', 'Traffic_Level',
#        'Vehicle_Type', 'Road_Type', 'Speed_Limit_kmh', 'Average_Speed_kmh',
#        'Pedestrian_Count', 'Visibility_Percent', 'Near_Miss_Score',
#        'Incident'],
#       dtype='str')
